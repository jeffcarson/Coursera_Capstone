# %% [markdown]
# Import Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.18.1-py_0 conda-forge
#
# geographiclib- 100% |################################| Time: 0:00:00  24.65 MB/s
# geopy-1.18.1-p 100% |################################| Time: 0:00:00  37.35 MB/s
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00  53.13 MB/s
# branca-0.3.1-p 100% |################################| Time: 0:00:00  37.10 MB/s
# vincent-0.4.4- 100% |################################| Time: 0:00:00  39.84 MB/s
# folium-0.5.0-p 100% |################################| Time: 0:00:00  48.80 MB/s
# Folium installed
# Libraries imported.

# %% [markdown]
# Establish Foursquare Crendentials

# %%
CLIENT_ID = 'PNWC3UG1LGIJTROW0HJZYEIFMBJ5RRC2PCCD2UMSZYKNQQKD' # your Foursquare ID
CLIENT_SECRET = '4GAGO34R0KVAL5VFESIDOPYB1EQ4CIJNVAM2MEOHOKPDIJP4' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 60
print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: PNWC3UG1LGIJTROW0HJZYEIFMBJ5RRC2PCCD2UMSZYKNQQKD
# CLIENT_SECRET:4GAGO34R0KVAL5VFESIDOPYB1EQ4CIJNVAM2MEOHOKPDIJP4

# %% [markdown]
# Convert Address Into Latitude and Longitude and Set Radius

# %%
#Pick center point of Dallas (Dallas City Hall)
address = '1500 Marilla St, Dallas, TX 75201'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
#radius is in meters. Dallas is approximately 385.8 square miles = 19.64 miles.  1 mile = 1,609.64 meters therefore 19.64 miles = approximately 31,611 meters. 
radius = 31611
# Out:
# 32.77627145 -96.7969417489513

# %% [markdown]
# Define URL

# %%
#(1) Farmers Market, (2) Fish Market (3) Grocery Store (4) Health Food Store (5) Organic Grocery (6) Supermarket (7) Fruit & Vegetable Store (8) Fast Food Restaurant (9) Convenience Store
url1 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&categoryId=4bf58dd8d48988d1fa941735&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,VERSION, radius, LIMIT)
url2 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&categoryId=4bf58dd8d48988d10e951735&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,VERSION, radius, LIMIT)
url3 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&categoryId=4bf58dd8d48988d118951735&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,VERSION, radius, LIMIT)
url4 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&categoryId=50aa9e744b90af0d42d5de0e&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,VERSION, radius, LIMIT)
url5 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&categoryId=52f2ab2ebcbc57f1066b8b45&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,VERSION, radius, LIMIT)
url6 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&categoryId=52f2ab2ebcbc57f1066b8b46&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,VERSION, radius, LIMIT)
url7 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&categoryId=52f2ab2ebcbc57f1066b8b1c&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,VERSION, radius, LIMIT)
url8 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&categoryId=4bf58dd8d48988d16e941735&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,VERSION, radius, LIMIT)
url9 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&categoryId=4d954b0ea243a5684a65b473&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,VERSION, radius, LIMIT)
url10 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&categoryId=4bf58dd8d48988d186941735&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,VERSION, radius, LIMIT)

# %% [markdown]
# Generate JSON File

# %%
#generate JSON File
import requests
results = requests.get(url10).json()
#results
'There are {} around Dallas City Hall.'.format(len(results['response']['venues']))
# Out:
# 'There are 50 around Dallas City Hall.'

# %%
#get relevant part of JSON
results2 = results['response']['venues']

#transform results2 into a dataframe
dataframe = json_normalize(results2) # flatten JSON
#dataframe.head()

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']


# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

#dataframe_filtered

# %% [markdown]
# Combining the 9 DataSets that were manually generated without a loop

# %%
farmers_market = dataframe_filtered
farmers_market.dropna(subset=['city'], inplace=True)
farmers_market = farmers_market[(farmers_market['city'].str.contains('Dallas'))]
farmers_market.head()
# Out:
#                     name      categories                   address  cc  \
# 4   Tyler Farmers Market  Farmers Market   510 S Good Latimer Expy  US
# 6   Paul's Fresh Produce  Farmers Market                       NaN  US
# 7      R L Graham & Sons  Farmers Market         1010 S Pearl Expy  US
# 8                 Shed 2  Farmers Market  at Dallas Farmers Market  US
# 12         Bueno Produce  Farmers Market                       NaN  US
#
#       city        country crossStreet  distance  \
# 4   Dallas  United States         NaN      1162
# 6   Dallas  United States         NaN       765
# 7   Dallas  United States         NaN       805
# 8   Dallas  United States         NaN       662
# 12  Dallas  United States         NaN       720
#
#                                      formattedAddress  \
# 4   [510 S Good Latimer Expy, Dallas, TX 75226, Un...
# 6                         [Dallas, TX, United States]
# 7   [1010 S Pearl Expy, Dallas, TX 75201, United S...
# 8   [at Dallas Farmers Market, Dallas, TX 75201, U...
# 12                        [Dallas, TX, United States]
#
#                                        labeledLatLngs        lat        lng  \
# 4   [{'lng': -96.785694, 'label': 'display', 'lat'...  32.780699 -96.785694
# 6   [{'lng': -96.788913, 'label': 'display', 'lat'...  32.777576 -96.788913
# 7   [{'lng': -96.788557, 'label': 'display', 'lat'...  32.777895 -96.788557
# 8   [{'lng': -96.79007416712155, 'label': 'display...  32.777701 -96.790074
# 12  [{'lng': -96.789346, 'label': 'display', 'lat'...  32.777298 -96.789346
#
#       neighborhood postalCode state                        id
# 4              NaN      75226    TX  4f32126f19833175d60dbb25
# 6              NaN        NaN    TX  4e764e8a1838f9188a3ae207
# 7              NaN      75201    TX  4e6d2881a80961d6fdbd947f
# 8   Farmers Market      75201    TX  4e1a0d87fa76194645a0dcf4
# 12             NaN        NaN    TX  4e6d274a62e1a462178f8933

# %%
fish_market = dataframe_filtered
fish_market.dropna(subset=['city'], inplace=True)
fish_market = fish_market[(fish_market['city'].str.contains('Dallas'))]
fish_market.loc[fish_market['categories'] =='Seafood Restaurant', 'categories'] = 'Fish Market'
fish_market.head()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#                                             name   categories  \
# 0  Amberjax Fish Market Grille at Trinity Groves  Fish Market
# 3                      Lovers Seafood And Market  Fish Market
# 5                            TJ's Seafood Market  Fish Market
#
#                address  cc    city        country    crossStreet  distance  \
# 0  3011 Gulden Ln #107  US  Dallas  United States      Singleton      2975
# 3     5200 W Lovers Ln  US  Dallas  United States  at Inwood Rd.      8660
# 5     11661 Preston Rd  US  Dallas  United States  at Forest Ln.     14637
#
#                                     formattedAddress  \
# 0  [3011 Gulden Ln #107 (Singleton), Dallas, TX 7...
# 3  [5200 W Lovers Ln (at Inwood Rd.), Dallas, TX ...
# 5  [11661 Preston Rd (at Forest Ln.), Dallas, TX ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'lng': -96.82851418400962, 'label': 'display...  32.779394 -96.828514
# 3  [{'lng': -96.82201882735626, 'label': 'display...  32.851161 -96.822019
# 5  [{'lng': -96.80565110513112, 'label': 'display...  32.907561 -96.805651
#
#   postalCode state                        id
# 0      75212    TX  52b34a0b11d2b3ce19fac570
# 3      75209    TX  4ae1e792f964a520928821e3
# 5      75230    TX  4be0a3332aed2d7f1808c96f

# %%
grocery_store = dataframe_filtered
grocery_store.dropna(subset=['city'], inplace=True)
grocery_store = grocery_store[(grocery_store['city'].str.contains('Dallas'))]
grocery_store.loc[grocery_store['categories'] =='Big Box Store', 'categories'] = 'Grocery Store'
grocery_store.loc[grocery_store['categories'] =='Gourmet Shop', 'categories'] = 'Grocery Store'
grocery_store.head()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#                  name     categories                address  cc    city  \
# 0  Whole Foods Market  Grocery Store   2510 McKinney Avenue  US  Dallas
# 3        Trader Joe's  Grocery Store          4525 Cole Ave  US  Dallas
# 5  Whole Foods Market  Grocery Store       2118 Abrams Road  US  Dallas
# 6      Central Market  Grocery Store       5750 E Lovers Ln  US  Dallas
# 7        Trader Joe's  Grocery Store  7939 Walnut Hill Lane  US  Dallas
#
#          country        crossStreet  distance  \
# 0  United States       at Routh St.      2217
# 3  United States                NaN      5120
# 5  United States   at Prospect Ave.      6057
# 6  United States  at Greenville Ave      8591
# 7  United States                NaN     11845
#
#                                     formattedAddress  \
# 0  [2510 McKinney Avenue (at Routh St.), Dallas, ...
# 3   [4525 Cole Ave, Dallas, TX 75205, United States]
# 5  [2118 Abrams Road (at Prospect Ave.), Dallas, ...
# 6  [5750 E Lovers Ln (at Greenville Ave), Dallas,...
# 7  [7939 Walnut Hill Lane, Dallas, TX 75230, Unit...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'lng': -96.80160215524401, 'label': 'display...  32.795804 -96.801602
# 3  [{'lng': -96.78986469259834, 'label': 'display...  32.821883 -96.789865
# 5  [{'lng': -96.75238743524041, 'label': 'display...  32.815754 -96.752387
# 6  [{'lng': -96.76868123575166, 'label': 'display...  32.849708 -96.768681
# 7  [{'lng': -96.77247615522731, 'label': 'display...  32.880681 -96.772476
#
#   neighborhood postalCode state                        id
# 0          NaN      75201    TX  55cb9fc5498ea925f27cbf69
# 3          NaN      75205    TX  56d89ae7cd1054a0b3fade4b
# 5     Lakewood      75214    TX  4a610518f964a520afc11fe3
# 6          NaN      75206    TX  4a5528b4f964a520c1b31fe3
# 7          NaN      75230    TX  54ff7695498ece66e64f5224

# %%
health_food_store = dataframe_filtered
health_food_store.dropna(subset=['city'], inplace=True)
health_food_store = health_food_store[(health_food_store['city'].str.contains('Dallas'))]
health_food_store.loc[health_food_store['categories'] =='Gluten-free Restaurant', 'categories'] = 'Health Food Store'
health_food_store.loc[health_food_store['categories'] =='Supplement Shop', 'categories'] = 'Health Food Store'
health_food_store.head()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#                      name         categories               address  cc  \
# 0      Whole Foods Market      Grocery Store  2510 McKinney Avenue  US
# 2      Whole Foods Market      Grocery Store      2118 Abrams Road  US
# 3            Snap Kitchen  Health Food Store      4115 Skillman St  US
# 6  Sprouts Farmers Market      Grocery Store      7110 Skillman St  US
# 8      Whole Foods Market      Grocery Store        8190 Park Lane  US
#
#      city        country            crossStreet  distance  \
# 0  Dallas  United States           at Routh St.      2217
# 2  Dallas  United States       at Prospect Ave.      6057
# 3  Dallas  United States  at E. Mockingbird Ln.      7444
# 6  Dallas  United States                    NaN     12569
# 8  Dallas  United States     at Greenville Ave.     11002
#
#                                     formattedAddress  \
# 0  [2510 McKinney Avenue (at Routh St.), Dallas, ...
# 2  [2118 Abrams Road (at Prospect Ave.), Dallas, ...
# 3  [4115 Skillman St (at E. Mockingbird Ln.), Dal...
# 6  [7110 Skillman St, Dallas, TX 75231, United St...
# 8  [8190 Park Lane (at Greenville Ave.), Dallas, ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'lng': -96.80160215524401, 'label': 'display...  32.795804 -96.801602
# 2  [{'lng': -96.75238743524041, 'label': 'display...  32.815754 -96.752387
# 3  [{'lng': -96.76174405212738, 'label': 'display...  32.836243 -96.761744
# 6  [{'lng': -96.7341862, 'label': 'display', 'lat...  32.876112 -96.734186
# 8  [{'lng': -96.76575690507887, 'label': 'display...  32.871568 -96.765757
#
#   neighborhood postalCode state                        id
# 0          NaN      75201    TX  55cb9fc5498ea925f27cbf69
# 2     Lakewood      75214    TX  4a610518f964a520afc11fe3
# 3          NaN      75206    TX  556b6acf498e1386e65e7fed
# 6          NaN      75231    TX  58d21c21af7d1762517e8829
# 8          NaN      75231    TX  4b54e0fdf964a52009d127e3

# %%
organic_grocery = dataframe_filtered
organic_grocery.dropna(subset=['city'], inplace=True)
organic_grocery = organic_grocery[(organic_grocery['city'].str.contains('Dallas'))]
organic_grocery.head()
# Out:
#                        name       categories                      address  cc  \
# 0            Stock Exchange  Organic Grocery                       Junius  US
# 2        Whole Foods Market    Grocery Store             2118 Abrams Road  US
# 5        Whole Foods Market    Grocery Store               8190 Park Lane  US
# 9   Vitality Bowls - Dallas       Restaurant  7865 Firefall Way,Suite 110  US
# 12          Natural Grocers  Organic Grocery    9400 Garland Rd Suite 150  US
#
#       city        country                           crossStreet  distance  \
# 0   Dallas  United States                                 Dumas      4253
# 2   Dallas  United States                      at Prospect Ave.      6057
# 5   Dallas  United States                    at Greenville Ave.     11002
# 9   Dallas  United States                                   NaN     11965
# 12  Dallas  United States  at Buckner in old Casa Linda theater     10872
#
#                                      formattedAddress  \
# 0   [Junius (Dumas), Dallas, TX 75214, United States]
# 2   [2118 Abrams Road (at Prospect Ave.), Dallas, ...
# 5   [8190 Park Lane (at Greenville Ave.), Dallas, ...
# 9   [7865 Firefall Way,Suite 110, Dallas, TX 75230...
# 12  [9400 Garland Rd Suite 150 (at Buckner in old ...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'lng': -96.763877, 'label': 'display', 'lat'...  32.802488 -96.763877
# 2   [{'lng': -96.75238743524041, 'label': 'display...  32.815754 -96.752387
# 5   [{'lng': -96.76575690507887, 'label': 'display...  32.871568 -96.765757
# 9   [{'lng': -96.77203519999999, 'label': 'display...  32.881707 -96.772035
# 12  [{'lng': -96.70204017675057, 'label': 'display...  32.832630 -96.702040
#
#    neighborhood postalCode state                        id
# 0           NaN      75214    TX  57adf7f6498e3ad15db46e64
# 2      Lakewood      75214    TX  4a610518f964a520afc11fe3
# 5           NaN      75231    TX  4b54e0fdf964a52009d127e3
# 9           NaN      75230    TX  5be2f4a5da5ede002cb75adb
# 12          NaN      75218    TX  4dc34cd718387d1bd506c661

# %%
supermarket = dataframe_filtered
supermarket.dropna(subset=['city'], inplace=True)
supermarket = supermarket[(supermarket['city'].str.contains('Dallas'))]
supermarket.loc[supermarket['categories'] =='Big Box Store', 'categories'] = 'Supermarket'
supermarket.head()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#                           name     categories                address  cc  \
# 0  Walmart Neighborhood Market  Grocery Store    2305 N Central Expy  US
# 2                 Trader Joe's  Grocery Store          4525 Cole Ave  US
# 4                 Trader Joe's  Grocery Store  7939 Walnut Hill Lane  US
# 7                       Kroger  Grocery Store  4142 Cedar Springs Rd  US
# 8                       Kroger  Grocery Store         4901 Maple Ave  US
#
#      city        country              crossStreet  distance  \
# 0  Dallas  United States                      NaN      2751
# 2  Dallas  United States                      NaN      5120
# 4  Dallas  United States                      NaN     11845
# 7  Dallas  United States          at Douglas Ave.      4379
# 8  Dallas  United States  at Medical District Dr.      5175
#
#                                     formattedAddress  \
# 0  [2305 N Central Expy, Dallas, TX 75204, United...
# 2   [4525 Cole Ave, Dallas, TX 75205, United States]
# 4  [7939 Walnut Hill Lane, Dallas, TX 75230, Unit...
# 7  [4142 Cedar Springs Rd (at Douglas Ave.), Dall...
# 8  [4901 Maple Ave (at Medical District Dr.), Dal...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'lng': -96.7939376939363, 'label': 'display'...  32.800860 -96.793938
# 2  [{'lng': -96.78986469259834, 'label': 'display...  32.821883 -96.789865
# 4  [{'lng': -96.77247615522731, 'label': 'display...  32.880681 -96.772476
# 7  [{'lng': -96.8123138, 'label': 'display', 'lat...  32.813432 -96.812314
# 8  [{'lng': -96.8292328, 'label': 'display', 'lat...  32.814019 -96.829233
#
#        neighborhood postalCode state                        id
# 0            Uptown      75204    TX  4aa6a9d2f964a5208a4a20e3
# 2               NaN      75205    TX  56d89ae7cd1054a0b3fade4b
# 4               NaN      75230    TX  54ff7695498ece66e64f5224
# 7               NaN      75219    TX  4afcaac1f964a520eb2422e3
# 8  Medical District      75235    TX  4f975ce4e4b01a1a3741e366

# %%
fruit_and_veggie = dataframe_filtered
fruit_and_veggie.dropna(subset=['city'], inplace=True)
fruit_and_veggie = fruit_and_veggie[(fruit_and_veggie['city'].str.contains('Dallas'))]
fruit_and_veggie.head()
# Out:
#                           name               categories  \
# 0            South Mill Dallas  Fruit & Vegetable Store
# 2                  Pickletopia  Fruit & Vegetable Store
# 5  Farmers Fruit And Vegetable  Fruit & Vegetable Store
# 6         The Best Sun Produce  Fruit & Vegetable Store
# 8   The Market at Bonton Farms  Fruit & Vegetable Store
#
#                    address  cc    city        country crossStreet  distance  \
# 0                      NaN  US  Dallas  United States         NaN       451
# 2            4812 Bryan St  US  Dallas  United States         NaN      3726
# 5  510 S Good Latimer Expy  US  Dallas  United States         NaN      1014
# 6                      NaN  US  Dallas  United States         NaN      1440
# 8        6907 Bexar Street  US  Dallas  United States         NaN      6130
#
#                                     formattedAddress  \
# 0                        [Dallas, TX, United States]
# 2   [4812 Bryan St, Dallas, TX 75204, United States]
# 5  [510 S Good Latimer Expy, Dallas, TX 75226, Un...
# 6                        [Dallas, TX, United States]
# 8  [6907 Bexar Street, Dallas, TX 75215, United S...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'lng': -96.80152331866807, 'label': 'display...  32.775005 -96.801523
# 2  [{'lng': -96.77354335784912, 'label': 'display...  32.803364 -96.773543
# 5  [{'lng': -96.78791237595031, 'label': 'display...  32.781310 -96.787912
# 6  [{'lng': -96.78267172095116, 'label': 'display...  32.771435 -96.782672
# 8  [{'lng': -96.753743, 'label': 'display', 'lat'...  32.734881 -96.753743
#
#   postalCode state                        id
# 0        NaN    TX  4e5af0801f6e804280da225b
# 2      75204    TX  5b9d69974c9be6002df3e21c
# 5      75226    TX  4d6276c21496370419bbfe94
# 6        NaN    TX  538799c1498e6050302e3df7
# 8      75215    TX  5b342532e65d0c002cb72508

# %%
fast_food = dataframe_filtered
fast_food.dropna(subset=['city'], inplace=True)
fast_food = fast_food[(fast_food['city'].str.contains('Dallas'))]
fast_food.loc[fast_food['categories'] =='Burger Joint', 'categories'] = 'Fast Food Restaurant'
fast_food.loc[fast_food['categories'] =='Fried Chicken Joint', 'categories'] = 'Fast Food Restaurant'
fast_food.head()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#             name            categories                address  cc    city  \
# 0     McDonald's  Fast Food Restaurant       1000 Commerce St  US  Dallas
# 1  Raising Canes  Fast Food Restaurant                    NaN  US  Dallas
# 4    Whataburger  Fast Food Restaurant    2741 N Stemmons Fwy  US  Dallas
# 5    Whataburger  Fast Food Restaurant      15255 Montfort Rd  US  Dallas
# 6    Chick-fil-A  Fast Food Restaurant  3040 W Mockingbird Ln  US  Dallas
#
#          country     crossStreet  distance  \
# 0  United States  at Griffin St.       629
# 1  United States             NaN      7313
# 4  United States       Inwood Rd      5940
# 5  United States             NaN     20332
# 6  United States             NaN      7361
#
#                                     formattedAddress  \
# 0  [1000 Commerce St (at Griffin St.), Dallas, TX...
# 1                  [Dallas, TX 75235, United States]
# 4  [2741 N Stemmons Fwy (Inwood Rd), Dallas, TX 7...
# 5  [15255 Montfort Rd, Dallas, TX 75248, United S...
# 6  [3040 W Mockingbird Ln, Dallas, TX 75235, Unit...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'lng': -96.803027, 'label': 'display', 'lat'...  32.778673 -96.803027
# 1  [{'lng': -96.84448813934186, 'label': 'display...  32.828422 -96.844488
# 4  [{'lng': -96.84708563073482, 'label': 'display...  32.808996 -96.847086
# 5  [{'lng': -96.81883407942543, 'label': 'display...  32.957997 -96.818834
# 6  [{'lng': -96.8391, 'label': 'display', 'lat': ...  32.832110 -96.839100
#
#        neighborhood postalCode state                        id
# 0               NaN      75202    TX  4a9a0019f964a520613120e3
# 1               NaN      75235    TX  59d42f8d9e0d540b4e11815f
# 4  Medical District      75207    TX  4b7649ebf964a520ce462ee3
# 5               NaN      75248    TX  4f42f81ee4b0561bfefb513c
# 6               NaN      75235    TX  5b4790d79f8a9f002cb44ec8

# %%
convenience_store = dataframe_filtered
convenience_store.dropna(subset=['city'], inplace=True)
convenience_store = convenience_store[(convenience_store['city'].str.contains('Dallas'))]
convenience_store.loc[convenience_store['categories'] =='Pharmacy', 'categories'] = 'Convenience Store'
convenience_store.loc[convenience_store['categories'] =='Gas Station'] = 'Convenience Store'
convenience_store.head()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#                 name         categories                address  cc    city  \
# 0           7-Eleven  Convenience Store          1010 Ross Ave  US  Dallas
# 1           QuikTrip  Convenience Store  1220 W Mockingbird Ln  US  Dallas
# 3           QuikTrip  Convenience Store          6055 Alpha Rd  US  Dallas
# 10          7-Eleven  Convenience Store    3976 Rosemeade Pkwy  US  Dallas
# 13  7-Eleven / Exxon  Convenience Store                    NaN  US  Dallas
#
#           country           crossStreet distance  \
# 0   United States                   NaN      948
# 1   United States                   NaN     8184
# 3   United States            Preston Rd    17500
# 10  United States  Rosemeade and Midway    26399
# 13  United States                   NaN    19712
#
#                                      formattedAddress  \
# 0    [1010 Ross Ave, Dallas, TX 75202, United States]
# 1   [1220 W Mockingbird Ln, Dallas, TX 75247, Unit...
# 3   [6055 Alpha Rd (Preston Rd), Dallas, TX 75240,...
# 10  [3976 Rosemeade Pkwy (Rosemeade and Midway), D...
# 13                        [Dallas, TX, United States]
#
#                                        labeledLatLngs      lat      lng  \
# 0   [{'lng': -96.8040034, 'label': 'display', 'lat...  32.7824  -96.804
# 1   [{'lng': -96.86773845798683, 'label': 'display...  32.8194 -96.8677
# 3   [{'lng': -96.80260006916568, 'label': 'display...  32.9334 -96.8026
# 10  [{'lng': -96.84447397293297, 'label': 'display...    33.01 -96.8445
# 13  [{'lng': -96.96365612360347, 'label': 'display...  32.8846 -96.9637
#
#    postalCode state                        id
# 0       75202    TX  50356ee6e4b0e6196d8e97e3
# 1       75247    TX  5a8b0b30018cbb60593f1d17
# 3       75240    TX  59064a20b546187ea5724430
# 10      75287    TX  4f163a21e4b067f6746bd1db
# 13        NaN    TX  55089b43498ead22f50a5d02

# %%
liquor_store = dataframe_filtered
liquor_store.dropna(subset=['city'], inplace=True)
liquor_store = liquor_store[(liquor_store['city'].str.contains('Dallas'))]
liquor_store.loc[liquor_store['categories'] =='Wine', 'categories'] = 'Liquor Store'
liquor_store.head()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#                            name    categories                address  cc  \
# 0                       Sigel's  Liquor Store  506 S Riverfront Blvd  US
# 1            Sowell Liquor Stoe  Liquor Store        2514 Hudnall St  US
# 2  Cheap River Liquor Beer Wine  Liquor Store  254 S Riverfront Blvd  US
# 3            Goody Goody Liquor  Liquor Store      7729 Garland Road  US
# 7                       Sigel's  Liquor Store    3209 N Fitzhugh Ave  US
#
#      city        country  crossStreet  distance  \
# 0  Dallas  United States          NaN      1471
# 1  Dallas  United States          NaN      5730
# 2  Dallas  United States          NaN      1487
# 3  Dallas  United States          NaN      7666
# 7  Dallas  United States  at Cole Ave      4484
#
#                                     formattedAddress  \
# 0  [506 S Riverfront Blvd, Dallas, TX 75207, Unit...
# 1  [2514 Hudnall St, Dallas, TX 75235, United Sta...
# 2  [254 S Riverfront Blvd, Dallas, TX 75207, Unit...
# 3  [7729 Garland Road, Dallas, TX 75218, United S...
# 7  [3209 N Fitzhugh Ave (at Cole Ave), Dallas, TX...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'lng': -96.81075387774584, 'label': 'display...  32.769953 -96.810754
# 1  [{'lng': -96.83240795221447, 'label': 'display...  32.818234 -96.832408
# 2  [{'lng': -96.81276798248291, 'label': 'display...  32.775088 -96.812768
# 3  [{'lng': -96.72728755174356, 'label': 'display...  32.812527 -96.727288
# 7  [{'lng': -96.79295228824145, 'label': 'display...  32.816414 -96.792952
#
#   postalCode state                        id
# 0      75207    TX  4bb51504941ad13a95b61de3
# 1      75235    TX  4cae44eceb65b1f7aa7f5acd
# 2      75207    TX  4f44abbb19836ed00195b4f3
# 3      75218    TX  57c1d09c498e59a8ba16adfd
# 7      75204    TX  4b467b0bf964a520462226e3

# %%
all_stores = [farmers_market, fish_market, grocery_store, health_food_store, organic_grocery, supermarket, fruit_and_veggie, fast_food, convenience_store, liquor_store]

combined_stores = pd.concat(all_stores)

# %%
#Drop Duplicate ID's
combined_stores.drop_duplicates(subset=['id'], keep=False)
# Out:
#                        address         categories  cc    city        country  \
# 4      510 S Good Latimer Expy     Farmers Market  US  Dallas  United States
# 6                          NaN     Farmers Market  US  Dallas  United States
# 7            1010 S Pearl Expy     Farmers Market  US  Dallas  United States
# 8     at Dallas Farmers Market     Farmers Market  US  Dallas  United States
# 12                         NaN     Farmers Market  US  Dallas  United States
# 17          920 S. Harwood Rd.     Farmers Market  US  Dallas  United States
# 19                         NaN     Farmers Market  US  Dallas  United States
# 21                         NaN     Farmers Market  US  Dallas  United States
# 26          10137 Shoreview Rd     Farmers Market  US  Dallas  United States
# 29    1718 S Good Latimer Expy     Farmers Market  US  Dallas  United States
# 30          702 N Buckner Blvd     Farmers Market  US  Dallas  United States
# 32                         NaN     Farmers Market  US  Dallas  United States
# 34                         NaN     Farmers Market  US  Dallas  United States
# 35                         NaN     Farmers Market  US  Dallas  United States
# 40                         NaN     Farmers Market  US  Dallas  United States
# 41          1410 Fitzhugh Ave.     Farmers Market  US  Dallas  United States
# 0          3011 Gulden Ln #107        Fish Market  US  Dallas  United States
# 3             5200 W Lovers Ln        Fish Market  US  Dallas  United States
# 5             11661 Preston Rd        Fish Market  US  Dallas  United States
# 6             5750 E Lovers Ln      Grocery Store  US  Dallas  United States
# 8         4349 W Northwest Hwy      Grocery Store  US  Dallas  United States
# 23        1800 N Henderson Ave      Grocery Store  US  Dallas  United States
# 3             4115 Skillman St  Health Food Store  US  Dallas  United States
# 6             7110 Skillman St      Grocery Store  US  Dallas  United States
# 12  3818 Cedar Springs Rd #101  Health Food Store  US  Dallas  United States
# 13                3001 Knox St  Health Food Store  US  Dallas  United States
# 16                         NaN  Health Food Store  US  Dallas  United States
# 19        4306 N. Central Expy  Health Food Store  US  Dallas  United States
# 28           4701 Frankford Rd  Health Food Store  US  Dallas  United States
# 29              Preston Center  Health Food Store  US  Dallas  United States
# ..                         ...                ...  ..     ...            ...
# 17            19020 Preston Rd  Convenience Store  US  Dallas  United States
# 18             511 S Zang Blvd  Convenience Store  US  Dallas  United States
# 19            5712 Skillman St  Convenience Store  US  Dallas  United States
# 20             2503 Lemmon Ave  Convenience Store  US  Dallas  United States
# 26             7818 Garland Rd  Convenience Store  US  Dallas  United States
# 30     3230 W Mockingbird Lane  Convenience Store  US  Dallas  United States
# 32              9500 Forest Ln  Convenience Store  US  Dallas  United States
# 43            10101 Royal Lane  Convenience Store  US  Dallas  United States
# 45            6060 Skillman Rd  Convenience Store  US  Dallas  United States
# 48         7104 Greenville Ave  Convenience Store  US  Dallas  United States
# 49             2501 N Field St  Convenience Store  US  Dallas  United States
# 0        506 S Riverfront Blvd       Liquor Store  US  Dallas  United States
# 1              2514 Hudnall St       Liquor Store  US  Dallas  United States
# 2        254 S Riverfront Blvd       Liquor Store  US  Dallas  United States
# 3            7729 Garland Road       Liquor Store  US  Dallas  United States
# 7          3209 N Fitzhugh Ave       Liquor Store  US  Dallas  United States
# 8        2800 Routh St Ste 180       Liquor Store  US  Dallas  United States
# 10         5757 Greenville Ave       Liquor Store  US  Dallas  United States
# 14            5748 Live Oak St       Liquor Store  US  Dallas  United States
# 15        1613 W Northwest Hwy       Liquor Store  US  Dallas  United States
# 19           3316 Oak Lawn Ave       Liquor Store  US  Dallas  United States
# 20         4724 Greenville Ave       Liquor Store  US  Dallas  United States
# 21         9500 N Central Expy       Liquor Store  US  Dallas  United States
# 22       4034 Cedar Springs Rd       Liquor Store  US  Dallas  United States
# 25       3600 W Jefferson Blvd       Liquor Store  US  Dallas  United States
# 30   9350 N Central Expressway       Liquor Store  US  Dallas  United States
# 33           2810 Samuell Blvd       Liquor Store  US  Dallas  United States
# 41                         NaN       Liquor Store  US  Dallas  United States
# 47    5360 W Lovers Ln Ste 200          Wine Shop  US  Dallas  United States
# 49               9972 Marsh Ln       Liquor Store  US  Dallas  United States
#
#                                 crossStreet distance  \
# 4                                       NaN     1162
# 6                                       NaN      765
# 7                                       NaN      805
# 8                                       NaN      662
# 12                                      NaN      720
# 17                             at Taylor St      731
# 19                                      NaN    10845
# 21                                      NaN    10294
# 26                                 Ferndale    12822
# 29                                      NaN     1474
# 30                               Northcliff    11110
# 32                                      NaN    11284
# 34                                      NaN     5168
# 35                                      NaN     6480
# 40                                      NaN    11706
# 41                             at Bryan St.     3784
# 0                                 Singleton     2975
# 3                             at Inwood Rd.     8660
# 5                             at Forest Ln.    14637
# 6                         at Greenville Ave     8591
# 8                                       NaN    10605
# 23                             at Lewis St.     4489
# 3                     at E. Mockingbird Ln.     7444
# 6                                       NaN    12569
# 12                                      NaN     3908
# 13                      at N. Central Expy.     4913
# 16                                      NaN     5177
# 19                                      NaN     4680
# 28                                      NaN    24949
# 29                                      NaN     9861
# ..                                      ...      ...
# 17                                      NaN    25807
# 18                                      NaN     4737
# 19                        Southwestern Blvd     9777
# 20                      at N. Central Expy.     2943
# 26                           at Winsted Dr.     7637
# 30                            at Ralston Av     7391
# 32                                 at I-635    16047
# 43                                      NaN    15335
# 45                          at Eastridge Dr    10542
# 48            btwn Holly Hill & Phoenix Drs    11490
# 49                                      NaN     1885
# 0                                       NaN     1471
# 1                                       NaN     5730
# 2                                       NaN     1487
# 3                                       NaN     7666
# 7                               at Cole Ave     4484
# 8                                 Howell St     2592
# 10  btwn Southwestern Blvd. & E. Lovers Ln.     9145
# 14                                      NaN     5076
# 15                               at Luna Rd    15690
# 19                        Oak Lawn/Rawlings     3927
# 20                               University     8120
# 21                       at Walnut Hill Ln.    11686
# 22                                   Knight     4209
# 25                                      NaN     8736
# 30            btwn Park Ln & Walnut Hill Ln    11255
# 33                          at Winslow Ave.     5090
# 41                                      NaN    13509
# 47           Inwood Village Shopping Center     8529
# 49                                      NaN    12753
#
#                                      formattedAddress  \
# 4   [510 S Good Latimer Expy, Dallas, TX 75226, Un...
# 6                         [Dallas, TX, United States]
# 7   [1010 S Pearl Expy, Dallas, TX 75201, United S...
# 8   [at Dallas Farmers Market, Dallas, TX 75201, U...
# 12                        [Dallas, TX, United States]
# 17  [920 S. Harwood Rd. (at Taylor St), Dallas, TX...
# 19                  [Dallas, TX 75231, United States]
# 21                  [Dallas, TX 75224, United States]
# 26  [10137 Shoreview Rd (Ferndale), Dallas, TX 752...
# 29  [1718 S Good Latimer Expy, Dallas, TX 75226, U...
# 30  [702 N Buckner Blvd (Northcliff), Dallas, TX 7...
# 32                  [Dallas, TX 75228, United States]
# 34                  [Dallas, TX 75208, United States]
# 35                  [Dallas, TX 75206, United States]
# 40                  [Dallas, TX 75241, United States]
# 41  [1410 Fitzhugh Ave. (at Bryan St.), Dallas, TX...
# 0   [3011 Gulden Ln #107 (Singleton), Dallas, TX 7...
# 3   [5200 W Lovers Ln (at Inwood Rd.), Dallas, TX ...
# 5   [11661 Preston Rd (at Forest Ln.), Dallas, TX ...
# 6   [5750 E Lovers Ln (at Greenville Ave), Dallas,...
# 8   [4349 W Northwest Hwy, Dallas, TX 75220, Unite...
# 23  [1800 N Henderson Ave (at Lewis St.), Dallas, ...
# 3   [4115 Skillman St (at E. Mockingbird Ln.), Dal...
# 6   [7110 Skillman St, Dallas, TX 75231, United St...
# 12  [3818 Cedar Springs Rd #101, Dallas, TX 75219,...
# 13  [3001 Knox St (at N. Central Expy.), Dallas, T...
# 16                  [Dallas, TX 75208, United States]
# 19  [4306 N. Central Expy, Dallas, TX 75206, Unite...
# 28  [4701 Frankford Rd, Dallas, TX 75287, United S...
# 29  [Preston Center, Dallas, TX 75225, United States]
# ..                                                ...
# 17  [19020 Preston Rd, Dallas, TX 75252, United St...
# 18  [511 S Zang Blvd, Dallas, TX 75208, United Sta...
# 19  [5712 Skillman St (Southwestern Blvd), Dallas,...
# 20  [2503 Lemmon Ave (at N. Central Expy.), Dallas...
# 26  [7818 Garland Rd (at Winsted Dr.), Dallas, TX ...
# 30  [3230 W Mockingbird Lane (at Ralston Av), Dall...
# 32  [9500 Forest Ln (at I-635), Dallas, TX 75243, ...
# 43  [10101 Royal Lane, Dallas, TX 75238, United St...
# 45  [6060 Skillman Rd (at Eastridge Dr), Dallas, T...
# 48  [7104 Greenville Ave (btwn Holly Hill & Phoeni...
# 49  [2501 N Field St, Dallas, TX 75201, United Sta...
# 0   [506 S Riverfront Blvd, Dallas, TX 75207, Unit...
# 1   [2514 Hudnall St, Dallas, TX 75235, United Sta...
# 2   [254 S Riverfront Blvd, Dallas, TX 75207, Unit...
# 3   [7729 Garland Road, Dallas, TX 75218, United S...
# 7   [3209 N Fitzhugh Ave (at Cole Ave), Dallas, TX...
# 8   [2800 Routh St Ste 180 (Howell St), Dallas, TX...
# 10  [5757 Greenville Ave (btwn Southwestern Blvd. ...
# 14  [5748 Live Oak St, Dallas, TX 75206, United St...
# 15  [1613 W Northwest Hwy (at Luna Rd), Dallas, TX...
# 19  [3316 Oak Lawn Ave (Oak Lawn/Rawlings), Dallas...
# 20  [4724 Greenville Ave (University), Dallas, TX ...
# 21  [9500 N Central Expy (at Walnut Hill Ln.), Dal...
# 22  [4034 Cedar Springs Rd (Knight), Dallas, TX 75...
# 25  [3600 W Jefferson Blvd, Dallas, TX 75211, Unit...
# 30  [9350 N Central Expressway (btwn Park Ln & Wal...
# 33  [2810 Samuell Blvd (at Winslow Ave.), Dallas, ...
# 41                  [Dallas, TX 75220, United States]
# 47  [5360 W Lovers Ln Ste 200 (Inwood Village Shop...
# 49   [9972 Marsh Ln, Dallas, TX 75220, United States]
#
#                           id  \
# 4   4f32126f19833175d60dbb25
# 6   4e764e8a1838f9188a3ae207
# 7   4e6d2881a80961d6fdbd947f
# 8   4e1a0d87fa76194645a0dcf4
# 12  4e6d274a62e1a462178f8933
# 17  4af47587f964a520aef221e3
# 19  504ba958e4b0f228d86497bc
# 21  5ac37b5da22db7732cdb095a
# 26  51573305e4b03caa1ce4b750
# 29  4f3bebd4e4b08230479d9d2f
# 30  4b9ba9e0f964a520091836e3
# 32  5b1ffd42acc5f5002cde601a
# 34  598f0301b37e2b18057e4787
# 35  4fc10ac2e4b051906880a5f8
# 40  5aaacabae96d0c3fbec24f2f
# 41  4c62d844ec94a59318412aca
# 0   52b34a0b11d2b3ce19fac570
# 3   4ae1e792f964a520928821e3
# 5   4be0a3332aed2d7f1808c96f
# 6   4a5528b4f964a520c1b31fe3
# 8   5b5125952f97ec002c65e7c7
# 23  4a6280a7f964a5202ec41fe3
# 3   556b6acf498e1386e65e7fed
# 6   58d21c21af7d1762517e8829
# 12  4b476058f964a520373026e3
# 13  5245f82911d2c572f8ce7512
# 16  5b3139a08d0a53002ce7cf15
# 19  4c125cbf82a3c9b69188f9f8
# 28  4c6861af607ad13a6285a82b
# 29  4e2334a1d22d0a3f5a0a1f00
# ..                       ...
# 17  529e8f4f11d2652c936b921a
# 18  55a92f82498e8961083907b8
# 19  4aea2607f964a520c5b921e3
# 20  500eeb1c6de406feaec6ae28
# 26  4bb496b35148d13a08ae523b
# 30  4b81c516f964a52010bd30e3
# 32  4f323894e4b0e6be3be294e6
# 43  51b1cc50498e2edd3351c68c
# 45  4c76ea7e93faa0935d3aeffb
# 48  4b369f35f964a5204e3925e3
# 49  57a76570498e8c3c69d9807f
# 0   4bb51504941ad13a95b61de3
# 1   4cae44eceb65b1f7aa7f5acd
# 2   4f44abbb19836ed00195b4f3
# 3   57c1d09c498e59a8ba16adfd
# 7   4b467b0bf964a520462226e3
# 8   4ab2bcd9f964a520166c20e3
# 10  4bd9ce24e914a5931ffd57fa
# 14  4ad8eff1f964a5202e1621e3
# 15  5201a273498ef351eefc8df2
# 19  4b6a029cf964a52097c12be3
# 20  4a97e066f964a520d72920e3
# 21  4ee8f86d5c5c99a2dc98faf0
# 22  4bdb5d523904a593b1084a9e
# 25  4c1525d2a5eb76b055d5c2b7
# 30  4fb15d35e4b0c824b983b499
# 33  4bacdf7af964a52056143be3
# 41  4be491a9d4f7c9b612572420
# 47  4b807ae2f964a520487630e3
# 49  541a0adc498ecf2b1d75658c
#
#                                        labeledLatLngs      lat      lng  \
# 4   [{'lng': -96.785694, 'label': 'display', 'lat'...  32.7807 -96.7857
# 6   [{'lng': -96.788913, 'label': 'display', 'lat'...  32.7776 -96.7889
# 7   [{'lng': -96.788557, 'label': 'display', 'lat'...  32.7779 -96.7886
# 8   [{'lng': -96.79007416712155, 'label': 'display...  32.7777 -96.7901
# 12  [{'lng': -96.789346, 'label': 'display', 'lat'...  32.7773 -96.7893
# 17  [{'lng': -96.78929, 'label': 'display', 'lat':...  32.7776 -96.7893
# 19  [{'lng': -96.76298905176012, 'label': 'display...  32.8694  -96.763
# 21  [{'lng': -96.842035, 'label': 'display', 'lat'...  32.6919  -96.842
# 26  [{'lng': -96.7109926579369, 'label': 'display'...   32.866  -96.711
# 29  [{'lng': -96.78120211227409, 'label': 'display...  32.7758 -96.7812
# 30  [{'lng': -96.711622, 'label': 'display', 'lat'...  32.8457 -96.7116
# 32  [{'lng': -96.681783, 'label': 'display', 'lat'...  32.8063 -96.6818
# 34  [{'lng': -96.838976, 'label': 'display', 'lat'...  32.7462  -96.839
# 35  [{'lng': -96.76111208504744, 'label': 'display...  32.8261 -96.7611
# 40  [{'lng': -96.752861, 'label': 'display', 'lat'...  32.6779 -96.7529
# 41  [{'lng': -96.77382900317737, 'label': 'display...  32.8042 -96.7738
# 0   [{'lng': -96.82851418400962, 'label': 'display...  32.7794 -96.8285
# 3   [{'lng': -96.82201882735626, 'label': 'display...  32.8512  -96.822
# 5   [{'lng': -96.80565110513112, 'label': 'display...  32.9076 -96.8057
# 6   [{'lng': -96.76868123575166, 'label': 'display...  32.8497 -96.7687
# 8   [{'lng': -96.836308, 'label': 'display', 'lat'...  32.8656 -96.8363
# 23  [{'lng': -96.77277356386185, 'label': 'display...  32.8111 -96.7728
# 3   [{'lng': -96.76174405212738, 'label': 'display...  32.8362 -96.7617
# 6   [{'lng': -96.7341862, 'label': 'display', 'lat...  32.8761 -96.7342
# 12  [{'lng': -96.80927400489269, 'label': 'display...  32.8098 -96.8093
# 13  [{'lng': -96.78762260016117, 'label': 'display...  32.8197 -96.7876
# 16  [{'lng': -96.842064, 'label': 'display', 'lat'...  32.7494 -96.8421
# 19  [{'lng': -96.787674, 'label': 'display', 'lat'...  32.8176 -96.7877
# 28  [{'lng': -96.82680685358852, 'label': 'display...   32.999 -96.8268
# 29  [{'lng': -96.80490818885245, 'label': 'display...  32.8646 -96.8049
# ..                                                ...      ...      ...
# 17  [{'lng': -96.79533474619669, 'label': 'display...  33.0081 -96.7953
# 18  [{'lng': -96.8249018741804, 'label': 'display'...  32.7408 -96.8249
# 19  [{'lng': -96.75591835300168, 'label': 'display...  32.8571 -96.7559
# 20  [{'lng': -96.7921979272251, 'label': 'display'...  32.8024 -96.7922
# 26  [{'lng': -96.7272596839083, 'label': 'display'...   32.812 -96.7273
# 30  [{'lng': -96.83700957421259, 'label': 'display...  32.8335  -96.837
# 32  [{'lng': -96.72959868047741, 'label': 'display...  32.9089 -96.7296
# 43  [{'lng': -96.71325704911374, 'label': 'display...  32.8947 -96.7133
# 45  [{'lng': -96.74967483717153, 'label': 'display...  32.8622 -96.7497
# 48  [{'lng': -96.76160847699492, 'label': 'display...  32.8751 -96.7616
# 49  [{'lng': -96.808048, 'label': 'display', 'lat'...  32.7904  -96.808
# 0   [{'lng': -96.81075387774584, 'label': 'display...    32.77 -96.8108
# 1   [{'lng': -96.83240795221447, 'label': 'display...  32.8182 -96.8324
# 2   [{'lng': -96.81276798248291, 'label': 'display...  32.7751 -96.8128
# 3   [{'lng': -96.72728755174356, 'label': 'display...  32.8125 -96.7273
# 7   [{'lng': -96.79295228824145, 'label': 'display...  32.8164  -96.793
# 8   [{'lng': -96.80269637313268, 'label': 'display...  32.7991 -96.8027
# 10  [{'lng': -96.76941182734849, 'label': 'display...  32.8551 -96.7694
# 14  [{'lng': -96.76211200817808, 'label': 'display...  32.8112 -96.7621
# 15  [{'lng': -96.92047523083288, 'label': 'display...  32.8716 -96.9205
# 19  [{'lng': -96.80683517527511, 'label': 'display...  32.8106 -96.8068
# 20  [{'lng': -96.76952431754805, 'label': 'display...  32.8455 -96.7695
# 21  [{'lng': -96.76915532371054, 'label': 'display...  32.8786 -96.7692
# 22  [{'lng': -96.81363293337354, 'label': 'display...  32.8114 -96.8136
# 25  [{'lng': -96.87970750436536, 'label': 'display...    32.74 -96.8797
# 30  [{'lng': -96.768189, 'label': 'display', 'lat'...  32.8745 -96.7682
# 33  [{'lng': -96.74620054172364, 'label': 'display...  32.7928 -96.7462
# 41  [{'lng': -96.8784571641066, 'label': 'display'...  32.8765 -96.8785
# 47  [{'lng': -96.82101237247514, 'label': 'display...  32.8502  -96.821
# 49  [{'lng': -96.85581981137574, 'label': 'display...  32.8796 -96.8558
#
#                                              name    neighborhood postalCode  \
# 4                            Tyler Farmers Market             NaN      75226
# 6                            Paul's Fresh Produce             NaN        NaN
# 7                               R L Graham & Sons             NaN      75201
# 8                                          Shed 2  Farmers Market      75201
# 12                                  Bueno Produce             NaN        NaN
# 17                          Dallas Farmers Market             NaN      75201
# 19                                    Viva Market             NaN      75231
# 21                                     Wic Market             NaN      75224
# 26                     Urban Acres Lake Highlands             NaN      75238
# 29                                  Taxco produce             NaN      75226
# 30                        White Rock Local Market             NaN      75218
# 32                                     WIC Market             NaN      75228
# 34                            Tyler Street Market             NaN      75208
# 35                       Urban Acres Co-op Pickup             NaN      75206
# 40              Paul Quinn College Farmers Market             NaN      75241
# 41                             Spiceman's FM 1410             NaN      75206
# 0   Amberjax Fish Market Grille at Trinity Groves             NaN      75212
# 3                       Lovers Seafood And Market             NaN      75209
# 5                             TJ's Seafood Market             NaN      75230
# 6                                  Central Market             NaN      75206
# 8                                  Central Market             NaN      75220
# 23                         Sprouts Farmers Market             NaN      75206
# 3                                    Snap Kitchen             NaN      75206
# 6                          Sprouts Farmers Market             NaN      75231
# 12                             Fitness Essentials         Oaklawn      75219
# 13                               Empire Nutrition             NaN      75205
# 16                                     Cbd Kratom             NaN      75208
# 19                  Sundrops Vitamins & Nutrition             NaN      75206
# 28                                            GNC             NaN      75287
# 29                      Ultimate Sports Nutrition             NaN      75225
# ..                                            ...             ...        ...
# 17                                       QuikTrip             NaN      75252
# 18                                       QuikTrip             NaN      75208
# 19                                       7-Eleven             NaN      75206
# 20                                       7-Eleven             NaN      75204
# 26                                       QuikTrip             NaN      75214
# 30                                       QuikTrip             NaN      75235
# 32                                       QuikTrip             NaN      75243
# 43                                       QuikTrip             NaN      75238
# 45                                       QuikTrip             NaN      75231
# 48                                       QuikTrip             NaN      75231
# 49                                   CVS pharmacy             NaN      75201
# 0                                         Sigel's             NaN      75207
# 1                              Sowell Liquor Stoe             NaN      75235
# 2                    Cheap River Liquor Beer Wine             NaN      75207
# 3                              Goody Goody Liquor             NaN      75218
# 7                                         Sigel's             NaN      75204
# 8                               Sigel's Beverages             NaN      75201
# 10                                        Sigel's             NaN      75206
# 14                      Medallion Discount Liquor             NaN      75206
# 15                   Spec's Wine and Liquor Store             NaN      75220
# 19                             Goody Goody Liquor             NaN      75219
# 20                                  Parkit Market             NaN      75206
# 21                                         Spec's             NaN      75231
# 22                                   Royal Liquor             NaN      75219
# 25                 Hill Town Beverage Beer & Wine             NaN      75211
# 30                              Total Wine & More             NaN      75231
# 33                                 Beverage Depot             NaN      75223
# 41                               Sigels Warehouse             NaN      75220
# 47                          Pogo's Wine & Spirits             NaN      75209
# 49                            Spec's Liquor Store             NaN      75220
#
#    state
# 4     TX
# 6     TX
# 7     TX
# 8     TX
# 12    TX
# 17    TX
# 19    TX
# 21    TX
# 26    TX
# 29    TX
# 30    TX
# 32    TX
# 34    TX
# 35    TX
# 40    TX
# 41    TX
# 0     TX
# 3     TX
# 5     TX
# 6     TX
# 8     TX
# 23    TX
# 3     TX
# 6     TX
# 12    TX
# 13    TX
# 16    TX
# 19    TX
# 28    TX
# 29    TX
# ..   ...
# 17    TX
# 18    TX
# 19    TX
# 20    TX
# 26    TX
# 30    TX
# 32    TX
# 43    TX
# 45    TX
# 48    TX
# 49    TX
# 0     TX
# 1     TX
# 2     TX
# 3     TX
# 7     TX
# 8     TX
# 10    TX
# 14    TX
# 15    TX
# 19    TX
# 20    TX
# 21    TX
# 22    TX
# 25    TX
# 30    TX
# 33    TX
# 41    TX
# 47    TX
# 49    TX
#
# [107 rows x 16 columns]

# %%
#List of Categories and Counts
temp_dataframe = combined_stores[['categories']]
category_counts = temp_dataframe.groupby(['categories']).size().reset_index(name='Total')
category_counts = category_counts.rename(columns={'categories': 'Venue Type'})
category_counts
# Out:
#                  Venue Type  Total
# 0         Convenience Store     17
# 1            Farmers Market     19
# 2      Fast Food Restaurant     20
# 3               Fish Market      3
# 4   Fruit & Vegetable Store      6
# 5    Gluten-free Restaurant      1
# 6              Gourmet Shop      2
# 7             Grocery Store     43
# 8         Health Food Store     22
# 9              Liquor Store     18
# 10          Organic Grocery      6
# 11              Supermarket      3
# 12          Supplement Shop      5
# 13                Wine Shop      1
# 14              supermarket      3

# %%
#List of Names and Counts
temp_dataframe = combined_stores[['name']]
name_counts = temp_dataframe.groupby(['name']).size().reset_index(name='Total')
name_counts = name_counts.rename(columns={'name': 'Name of Venue'})
name_counts
# Out:
#                                     Name of Venue  Total
# 0                                        7-Eleven      5
# 1                                7-Eleven / Exxon      1
# 2   Amberjax Fish Market Grille at Trinity Groves      1
# 3               Ann's Health Food Center & Market      2
# 4                                  Beverage Depot      1
# 5                Bountiful Baskets Garland Pickup      1
# 6                                   Bueno Produce      1
# 7                                    CVS pharmacy      1
# 8                                      Cbd Kratom      2
# 9                                  Central Market      5
# 10                   Cheap River Liquor Beer Wine      1
# 11                                    Chick-fil-A      7
# 12                               Cox Farms Market      3
# 13                          Dallas Farmers Market      1
# 14                               Empire Nutrition      2
# 15                    Farmers Fruit And Vegetable      1
# 16                             Fitness Essentials      2
# 17                                            GNC     10
# 18                             Goody Goody Liquor      2
# 19                                    Grabbagreen      2
# 20                 Hill Town Beverage Beer & Wine      1
# 21                                In-N-Out Burger      1
# 22                                         Kroger     12
# 23                      Lovers Seafood And Market      1
# 24                                     McDonald's      3
# 25                      Medallion Discount Liquor      1
# 26                                Natural Grocers      6
# 27                                  Parkit Market      1
# 28              Paul Quinn College Farmers Market      1
# 29                           Paul's Fresh Produce      1
# ..                                            ...    ...
# 42                              South Mill Dallas      1
# 43                             Sowell Liquor Stoe      1
# 44                                         Spec's      1
# 45                            Spec's Liquor Store      1
# 46                   Spec's Wine and Liquor Store      1
# 47                             Spiceman's FM 1410      1
# 48                         Sprouts Farmers Market      3
# 49                  Sundrops Vitamins & Nutrition      2
# 50                            TJ's Seafood Market      1
# 51                                  Taxco produce      1
# 52                           The Best Sun Produce      1
# 53                     The Market at Bonton Farms      1
# 54                                      Tom Thumb      4
# 55                                Total Nutrition      2
# 56                              Total Wine & More      1
# 57                                   Trader Joe's      7
# 58                           Tyler Farmers Market      1
# 59                            Tyler Street Market      1
# 60                      Ultimate Sports Nutrition      2
# 61                       Urban Acres Co-op Pickup      1
# 62                     Urban Acres Lake Highlands      1
# 63                                    Viva Market      1
# 64                                     WIC Market      1
# 65                    Walmart Neighborhood Market      2
# 66                            Walmart Supercenter      6
# 67                                        Wendy's      1
# 68                                    Whataburger      6
# 69                        White Rock Local Market      1
# 70                             Whole Foods Market     12
# 71                                     Wic Market      1
#
# [72 rows x 2 columns]

# %%
#List of Zip Codes and Counts
temp_dataframe = combined_stores[['postalCode']]
zip_counts = temp_dataframe.groupby(['postalCode']).size().reset_index(name='Total')
zip_counts = zip_counts.rename(columns={'postalCode': 'Zip Code'})
zip_counts
# Out:
#    Zip Code  Total
# 0     75080      2
# 1     75201      8
# 2     75202      2
# 3     75204      9
# 4     75205      4
# 5     75206     19
# 6     75207      3
# 7     75208      8
# 8     75209      7
# 9     75211      1
# 10    75212      1
# 11    75214      5
# 12    75215      1
# 13    75218      5
# 14    75219      7
# 15    75220      5
# 16    75223      1
# 17    75224      3
# 18    75225      4
# 19    75226      3
# 20    75228      1
# 21    75230     11
# 22    75231     15
# 23    75235      8
# 24    75237      2
# 25    75238      4
# 26    75240      2
# 27    75241      1
# 28    75243      4
# 29    75244      2
# 30    75246      1
# 31    75247      1
# 32    75248      3
# 33    75252      1
# 34    75254      2
# 35    75261      2
# 36    75287      5

# %% [markdown]
# Cluster Lat and Long

# %%
#Plot Clusters
# Initialize the plot with the specified dimensions.
fig = plt.figure(figsize=(6, 4))

# Colors uses a color map, which will produce an array of colors based on
# the number of labels there are. We use set(k_means_labels) to get the
# unique labels.
colors = plt.cm.Spectral(np.linspace(0, 1, len(set(k_means_labels))))

# Create a plot
ax = fig.add_subplot(1, 1, 1)

# For loop that plots the data points and centroids.
# k will range from 0-3, which will match the possible clusters that each
# data point is in.
for k, col in zip(range(len([[4,4], [-2, -1], [2, -3], [1, 1]])), colors):

    # Create a list of all data points, where the data poitns that are 
    # in the cluster (ex. cluster 0) are labeled as true, else they are
    # labeled as false.
    my_members = (k_means_labels == k)
    
    # Define the centroid, or cluster center.
    cluster_center = k_means_cluster_centers[k]
        
    # Plots the datapoints with color col.
    ax.plot(FinalData[my_members, 0], FinalData[my_members, 1], 'w', markerfacecolor=col, marker='.')
    
    # Plots the centroids with specified color, but with a darker outline
    ax.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col,  markeredgecolor='k', markersize=6)

# Title of the plot
ax.set_title('KMeans')

# Remove x-axis ticks
ax.set_xticks(())

# Remove y-axis ticks
ax.set_yticks(())

# Show the plot
plt.show()

# %%
#Drop Categorical Variables and Create a Unique Key
FinalData = combined_stores[['lat','lng']]
FinalData['UniqueKey']=np.arange(len(FinalData))
FinalData
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#         lat      lng  UniqueKey
# 4   32.7807 -96.7857          0
# 6   32.7776 -96.7889          1
# 7   32.7779 -96.7886          2
# 8   32.7777 -96.7901          3
# 12  32.7773 -96.7893          4
# 17  32.7776 -96.7893          5
# 19  32.8694  -96.763          6
# 21  32.6919  -96.842          7
# 26   32.866  -96.711          8
# 29  32.7758 -96.7812          9
# 30  32.8457 -96.7116         10
# 32  32.8063 -96.6818         11
# 34  32.7462  -96.839         12
# 35  32.8261 -96.7611         13
# 40  32.6779 -96.7529         14
# 41  32.8042 -96.7738         15
# 43  32.7698 -96.8354         16
# 0   32.7794 -96.8285         17
# 3   32.8512  -96.822         18
# 5   32.9076 -96.8057         19
# 0   32.7958 -96.8016         20
# 3   32.8219 -96.7899         21
# 5   32.8158 -96.7524         22
# 6   32.8497 -96.7687         23
# 7   32.8807 -96.7725         24
# 8   32.8656 -96.8363         25
# 11  32.8134 -96.8123         26
# 12   32.814 -96.8292         27
# 15  32.8148 -96.7705         28
# 17   32.959 -96.8167         29
# ..      ...      ...        ...
# 17  33.0081 -96.7953        123
# 18  32.7408 -96.8249        124
# 19  32.8571 -96.7559        125
# 20  32.8024 -96.7922        126
# 26   32.812 -96.7273        127
# 30  32.8335  -96.837        128
# 32  32.9089 -96.7296        129
# 43  32.8947 -96.7133        130
# 45  32.8622 -96.7497        131
# 48  32.8751 -96.7616        132
# 49  32.7904  -96.808        133
# 0     32.77 -96.8108        134
# 1   32.8182 -96.8324        135
# 2   32.7751 -96.8128        136
# 3   32.8125 -96.7273        137
# 7   32.8164  -96.793        138
# 8   32.7991 -96.8027        139
# 10  32.8551 -96.7694        140
# 14  32.8112 -96.7621        141
# 15  32.8716 -96.9205        142
# 19  32.8106 -96.8068        143
# 20  32.8455 -96.7695        144
# 21  32.8786 -96.7692        145
# 22  32.8114 -96.8136        146
# 25    32.74 -96.8797        147
# 30  32.8745 -96.7682        148
# 33  32.7928 -96.7462        149
# 41  32.8765 -96.8785        150
# 47  32.8502  -96.821        151
# 49  32.8796 -96.8558        152
#
# [153 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs 

#Normalize the Dataframe
Clus_dataSet = StandardScaler().fit_transform(FinalData)

# %%
#Cluster the Dataset
clusterNum = 3
k_means = KMeans(init = "k-means++", n_clusters = clusterNum, n_init = 12)
k_means.fit(Clus_dataSet)
k_means_labels = k_means.labels_

#Assign Labels to each Row
FinalData["Clus_km"] = k_means_labels

#Get Coordinates of Cluster Centers
k_means_cluster_centers = k_means.cluster_centers_
#k_means_cluster_centers

# %% [markdown]
# Visualize items on the map around our location

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around Dallas City Hall

# add a red circle marker to represent Dallas City Hall
folium.features.CircleMarker(
    [latitude, longitude],
    radius=4,
    color='grey',
    popup='Dallas City Hall',
    fill = True,
    fill_color = 'grey',
    fill_opacity = 1
).add_to(venues_map)

# add the Farmer's Market locations as blue circle markers
for lat, lng, label in zip(farmers_market.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=1
    ).add_to(venues_map)

        # add the Fish Market locations as green circle markers
for lat, lng, label in zip(fish_market.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=1
    ).add_to(venues_map)

        # add the Grocery Store locations as yellow circle markers
for lat, lng, label in zip(grocery_store.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=1
    ).add_to(venues_map)
    
        # add the Health Food Store locations as yellow circle markers
for lat, lng, label in zip(health_food_store.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
       radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=1
    ).add_to(venues_map)
    
        # add the Organic Grocery locations as yellow circle markers
for lat, lng, label in zip(organic_grocery.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=1
    ).add_to(venues_map)
    
        # add the Supermarket locations as yellow circle markers
for lat, lng, label in zip(supermarket.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=1
    ).add_to(venues_map)
    
        # add the Fruit & Vegetable Store locations as yellow circle markers
for lat, lng, label in zip(fruit_and_veggie.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=1
    ).add_to(venues_map)
    
        # add the Fast Food locations as yellow circle markers
for lat, lng, label in zip(fast_food.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
       color='red',
        popup=label,
        fill = True,
        fill_color='red',
        fill_opacity=1
    ).add_to(venues_map)
    
        # add the Convenience Store locations as yellow circle markers
for lat, lng, label in zip(convenience_store.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='red',
        popup=label,
        fill = True,
        fill_color='red',
        fill_opacity=1
    ).add_to(venues_map)
    
        # add the Liquor Store locations as yellow circle markers
for lat, lng, label in zip(liquor_store.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='black',
        popup=label,
        fill = True,
        fill_color='black',
        fill_opacity=1
    ).add_to(venues_map)

# display map
venues_map
